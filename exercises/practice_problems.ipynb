# %% [markdown]
# # Practice Problems
#
# These problems give you small astronomy-flavored datasets so you can practice
# the ideas from the course. Try the prediction first, then write code.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-whitegrid")

# %% [markdown]
# ## Problem 1: Typical Brightness
#
# The relative brightnesses below include one unusually bright object. Compute
# the mean and median, then decide which better describes a typical star.

# %%
brightness = np.array([0.91, 0.95, 1.02, 1.07, 1.10, 4.60])

# TODO: replace None with calculations.
mean_brightness = None
median_brightness = None

print(mean_brightness, median_brightness)

# %% [markdown]
# ## Problem 2: Photon Counts
#
# A faint source is observed ten times. Plot the photon counts and compute the
# average count.

# %%
photon_counts = np.array([2, 4, 1, 3, 5, 2, 3, 4, 0, 3])

# TODO: compute the average and make a bar chart.
average_count = None
print(average_count)

# %% [markdown]
# ## Problem 3: Transit Interpretation
#
# In one sentence, explain why a possible exoplanet transit should be evaluated
# against the noise level of the star's brightness measurements.

# %%
transit_explanation = ""

if transit_explanation:
    print(transit_explanation)
else:
    print("Write your explanation here.")
